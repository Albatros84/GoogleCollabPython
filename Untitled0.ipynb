# %% [markdown]
# <a href="https://colab.research.google.com/github/Albatros84/GoogleCollabPython/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello collab")
# Out:
# hello collab

# %%
print("hello Collab")
